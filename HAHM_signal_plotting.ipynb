# %%
from DarkPhotonModel import DarkPhotonModel

# %%
title_list = [r"Num. of $gg \to h \to A' A' \to 4\mu$ events", r"Num. of $gg \to h \to A' A' \to 2\mu + X$ events"]

# %%
Ap_model1 = DarkPhotonModel(BR_hApAp=1e-4, Lmin=0.001, Lmax=0.3)
Ap_model1.plot_num_sig(title_list)

# %%
Ap_model1.plot_num_sig_massgrid(title_list)

# %%
Ap_model2 = DarkPhotonModel(BR_hApAp=1e-4, Lmin=0.07, Lmax=0.3)
Ap_model2.plot_num_sig(title_list)

# %%
Ap_model3 = DarkPhotonModel(BR_hApAp=1e-5, Lmin=0.07, Lmax=0.3)
Ap_model3.plot_num_sig(title_list)
